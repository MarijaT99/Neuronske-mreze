# %%
# !rm -rf Neuronske-mreze
# !git clone https://github.com/MarijaT99/Neuronske-mreze.git
# %cd Neuronske-mreze
# Out:
# Cloning into 'Neuronske-mreze'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 160 (delta 62), reused 132 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (160/160), 2.09 MiB | 9.79 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /kaggle/working/Neuronske-mreze

# %%
DATA_ROOT = "/kaggle/input/datasets/abdallahalidev/plantvillage-dataset/color"

# %%
# !python scripts/train_flat.py    --data-root "{DATA_ROOT}" --model resnet50        --epochs 8  --device cuda --num-workers 4
# !python scripts/train_flat.py    --data-root "{DATA_ROOT}" --model efficientnet_b0 --epochs 8  --device cuda --num-workers 4
# !python scripts/train_flat.py    --data-root "{DATA_ROOT}" --model baseline_cnn    --epochs 25 --device cuda --num-workers 4
# !python scripts/train_species.py --data-root "{DATA_ROOT}" --model resnet50        --epochs 10 --device cuda --num-workers 4
# !python scripts/train_disease.py --data-root "{DATA_ROOT}" --model resnet50        --epochs 12 --device cuda --num-workers 4
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 172MB/s]
# Model: resnet50 | train: 38013 | val: 8146 | uredjaj: cuda
# Epoha 1/8  train_loss=0.2785  val_macro_f1=0.9225
# Epoha 2/8  train_loss=0.1040  val_macro_f1=0.9756
# Epoha 3/8  train_loss=0.0758  val_macro_f1=0.9609
# Epoha 4/8  train_loss=0.0626  val_macro_f1=0.9796
# Epoha 5/8  train_loss=0.0583  val_macro_f1=0.9764
# Epoha 6/8  train_loss=0.0508  val_macro_f1=0.9679
# Epoha 7/8  train_loss=0.0468  val_macro_f1=0.9854
# Epoha 8/8  train_loss=0.0399  val_macro_f1=0.9842
# Najbolji: epoha 7, val macro F1 = 0.9854
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 209MB/s]
# Model: efficientnet_b0 | train: 38013 | val: 8146 | uredjaj: cuda
# Epoha 1/8  train_loss=0.2441  val_macro_f1=0.9794
# Epoha 2/8  train_loss=0.0905  val_macro_f1=0.9769
# Epoha 3/8  train_loss=0.0737  val_macro_f1=0.9813
# Epoha 4/8  train_loss=0.0607  val_macro_f1=0.9840
# Epoha 5/8  train_loss=0.0543  val_macro_f1=0.9909
# Epoha 6/8  train_loss=0.0508  val_macro_f1=0.9869
# Epoha 7/8  train_loss=0.0494  val_macro_f1=0.9848
# Epoha 8/8  train_loss=0.0417  val_macro_f1=0.9863
# Najbolji: epoha 5, val macro F1 = 0.9909
# Model: baseline_cnn | train: 38013 | val: 8146 | uredjaj: cuda
# Epoha 1/25  train_loss=1.9174  val_macro_f1=0.5990
# Epoha 2/25  train_loss=0.7976  val_macro_f1=0.6722
# Epoha 3/25  train_loss=0.5780  val_macro_f1=0.8359
# Epoha 4/25  train_loss=0.4517  val_macro_f1=0.8337
# Epoha 5/25  train_loss=0.3555  val_macro_f1=0.8406
# Epoha 6/25  train_loss=0.3002  val_macro_f1=0.8843
# Epoha 7/25  train_loss=0.2666  val_macro_f1=0.9053
# Epoha 8/25  train_loss=0.2287  val_macro_f1=0.9232
# Epoha 9/25  train_loss=0.2054  val_macro_f1=0.9245
# Epoha 10/25  train_loss=0.1810  val_macro_f1=0.9349
# Epoha 11/25  train_loss=0.1668  val_macro_f1=0.9376
# Epoha 12/25  train_loss=0.1548  val_macro_f1=0.9483
# Epoha 13/25  train_loss=0.1392  val_macro_f1=0.9593
# Epoha 14/25  train_loss=0.1250  val_macro_f1=0.9503
# Epoha 15/25  train_loss=0.1227  val_macro_f1=0.9294
# Epoha 16/25  train_loss=0.1130  val_macro_f1=0.9540
# Epoha 17/25  train_loss=0.1028  val_macro_f1=0.9602
# Epoha 18/25  train_loss=0.0989  val_macro_f1=0.9601
# Epoha 19/25  train_loss=0.0916  val_macro_f1=0.9641
# Epoha 20/25  train_loss=0.0904  val_macro_f1=0.9667
# Epoha 21/25  train_loss=0.0815  val_macro_f1=0.9702
# Epoha 22/25  train_loss=0.0790  val_macro_f1=0.9692
# Epoha 23/25  train_loss=0.0733  val_macro_f1=0.9728
# Epoha 24/25  train_loss=0.0724  val_macro_f1=0.9685
# Epoha 25/25  train_loss=0.0681  val_macro_f1=0.9670
# Najbolji: epoha 23, val macro F1 = 0.9728
# [VRSTA] Model: resnet50 | train: 38013 | val: 8146
# Epoha 1/10  train_loss=0.1321  val_macro_f1=0.9966
# Epoha 2/10  train_loss=0.0169  val_macro_f1=0.9979
# Epoha 3/10  train_loss=0.0116  val_macro_f1=0.9991
# Epoha 4/10  train_loss=0.0079  val_macro_f1=0.9952
# Epoha 5/10  train_loss=0.0095  val_macro_f1=0.9947
# Epoha 6/10  train_loss=0.0091  val_macro_f1=0.9969
# Epoha 7/10  train_loss=0.0050  val_macro_f1=0.9994
# Epoha 8/10  train_loss=0.0061  val_macro_f1=0.9987
# Epoha 9/10  train_loss=0.0062  val_macro_f1=0.9987
# Epoha 10/10  train_loss=0.0042  val_macro_f1=0.9991
# Najbolji: epoha 7, val macro F1 = 0.9994
#
# [BOLEST] Apple: 4 klasa | train: 2220 | val: 476
# Epoha 1/12  train_loss=0.4307  val_macro_f1=0.9844
# Epoha 2/12  train_loss=0.0583  val_macro_f1=0.9913
# Epoha 3/12  train_loss=0.0147  val_macro_f1=1.0000
# Epoha 4/12  train_loss=0.0203  val_macro_f1=1.0000
# Epoha 5/12  train_loss=0.0143  val_macro_f1=0.9947
# Epoha 6/12  train_loss=0.0076  val_macro_f1=0.9963
# Epoha 7/12  train_loss=0.0124  val_macro_f1=0.9982
# Epoha 8/12  train_loss=0.0050  val_macro_f1=1.0000
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 3, val macro F1 = 1.0000
# Preskacem 'Blueberry' (samo 1 klasa).
#
# [BOLEST] Cherry_(including_sour): 2 klasa | train: 1334 | val: 286
# Epoha 1/12  train_loss=0.1822  val_macro_f1=1.0000
# Epoha 2/12  train_loss=0.0066  val_macro_f1=0.9965
# Epoha 3/12  train_loss=0.0055  val_macro_f1=0.9965
# Epoha 4/12  train_loss=0.0024  val_macro_f1=0.9965
# Epoha 5/12  train_loss=0.0012  val_macro_f1=0.9965
# Epoha 6/12  train_loss=0.0010  val_macro_f1=0.9965
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 1, val macro F1 = 1.0000
#
# [BOLEST] Corn_(maize): 4 klasa | train: 2696 | val: 578
# Epoha 1/12  train_loss=0.4065  val_macro_f1=0.9442
# Epoha 2/12  train_loss=0.0878  val_macro_f1=0.9520
# Epoha 3/12  train_loss=0.0571  val_macro_f1=0.9485
# Epoha 4/12  train_loss=0.0388  val_macro_f1=0.9711
# Epoha 5/12  train_loss=0.0337  val_macro_f1=0.9657
# Epoha 6/12  train_loss=0.0324  val_macro_f1=0.9663
# Epoha 7/12  train_loss=0.0191  val_macro_f1=0.9733
# Epoha 8/12  train_loss=0.0140  val_macro_f1=0.9726
# Epoha 9/12  train_loss=0.0240  val_macro_f1=0.9729
# Epoha 10/12  train_loss=0.0213  val_macro_f1=0.9696
# Epoha 11/12  train_loss=0.0137  val_macro_f1=0.9724
# Epoha 12/12  train_loss=0.0113  val_macro_f1=0.9535
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 7, val macro F1 = 0.9733
#
# [BOLEST] Grape: 4 klasa | train: 2844 | val: 610
# Epoha 1/12  train_loss=0.3218  val_macro_f1=0.9974
# Epoha 2/12  train_loss=0.0245  val_macro_f1=0.9987
# Epoha 3/12  train_loss=0.0242  val_macro_f1=1.0000
# Epoha 4/12  train_loss=0.0131  val_macro_f1=1.0000
# Epoha 5/12  train_loss=0.0056  val_macro_f1=1.0000
# Epoha 6/12  train_loss=0.0090  val_macro_f1=0.9961
# Epoha 7/12  train_loss=0.0084  val_macro_f1=1.0000
# Epoha 8/12  train_loss=0.0181  val_macro_f1=1.0000
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 3, val macro F1 = 1.0000
# Preskacem 'Orange' (samo 1 klasa).
#
# [BOLEST] Peach: 2 klasa | train: 1860 | val: 398
# Epoha 1/12  train_loss=0.1724  val_macro_f1=0.9895
# Epoha 2/12  train_loss=0.0157  val_macro_f1=0.9947
# Epoha 3/12  train_loss=0.0200  val_macro_f1=0.9946
# Epoha 4/12  train_loss=0.0053  val_macro_f1=1.0000
# Epoha 5/12  train_loss=0.0024  val_macro_f1=0.9947
# Epoha 6/12  train_loss=0.0063  val_macro_f1=1.0000
# Epoha 7/12  train_loss=0.0013  val_macro_f1=1.0000
# Epoha 8/12  train_loss=0.0059  val_macro_f1=1.0000
# Epoha 9/12  train_loss=0.0138  val_macro_f1=1.0000
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 4, val macro F1 = 1.0000
#
# [BOLEST] Pepper,_bell: 2 klasa | train: 1732 | val: 371
# Epoha 1/12  train_loss=0.1996  val_macro_f1=0.9972
# Epoha 2/12  train_loss=0.0225  val_macro_f1=1.0000
# Epoha 3/12  train_loss=0.0084  val_macro_f1=1.0000
# Epoha 4/12  train_loss=0.0097  val_macro_f1=1.0000
# Epoha 5/12  train_loss=0.0216  val_macro_f1=1.0000
# Epoha 6/12  train_loss=0.0049  val_macro_f1=1.0000
# Epoha 7/12  train_loss=0.0106  val_macro_f1=1.0000
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 2, val macro F1 = 1.0000
#
# [BOLEST] Potato: 3 klasa | train: 1506 | val: 323
# Epoha 1/12  train_loss=0.4209  val_macro_f1=0.9804
# Epoha 2/12  train_loss=0.0503  val_macro_f1=1.0000
# Epoha 3/12  train_loss=0.0273  val_macro_f1=0.9915
# Epoha 4/12  train_loss=0.0392  val_macro_f1=0.9918
# Epoha 5/12  train_loss=0.0374  val_macro_f1=0.9918
# Epoha 6/12  train_loss=0.0227  val_macro_f1=1.0000
# Epoha 7/12  train_loss=0.0180  val_macro_f1=0.9918
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 2, val macro F1 = 1.0000
# Preskacem 'Raspberry' (samo 1 klasa).
# Preskacem 'Soybean' (samo 1 klasa).
# Preskacem 'Squash' (samo 1 klasa).
#
# [BOLEST] Strawberry: 2 klasa | train: 1097 | val: 234
# Epoha 1/12  train_loss=0.2212  val_macro_f1=1.0000
# Epoha 2/12  train_loss=0.0090  val_macro_f1=1.0000
# Epoha 3/12  train_loss=0.0052  val_macro_f1=1.0000
# Epoha 4/12  train_loss=0.0039  val_macro_f1=1.0000
# Epoha 5/12  train_loss=0.0015  val_macro_f1=1.0000
# Epoha 6/12  train_loss=0.0011  val_macro_f1=1.0000
# Early stopping: nema poboljsanja 5 epoha zaredom.
# Najbolji: epoha 1, val macro F1 = 1.0000
#
# [BOLEST] Tomato: 10 klasa | train: 12710 | val: 2725
# Epoha 1/12  train_loss=0.3916  val_macro_f1=0.9850
# Epoha 2/12  train_loss=0.0700  val_macro_f1=0.9936
# Epoha 3/12  train_loss=0.0416  val_macro_f1=0.9853
# Epoha 4/12  train_loss=0.0332  val_macro_f1=0.9978
# Epoha 5/12  train_loss=0.0288  val_macro_f1=0.9909
# Epoha 6/12  train_loss=0.0219  val_macro_f1=0.9986
# Epoha 7/12  train_loss=0.0136  val_macro_f1=0.9871
# Epoha 8/12  train_loss=0.0225  val_macro_f1=0.9975
# Epoha 9/12  train_loss=0.0128  val_macro_f1=0.9967
# Epoha 10/12  train_loss=0.0138  val_macro_f1=0.9955
# Epoha 11/12  train_loss=0.0090  val_macro_f1=0.9991
# Epoha 12/12  train_loss=0.0152  val_macro_f1=0.9935
# Najbolji: epoha 11, val macro F1 = 0.9991

# %%
# !python scripts/evaluate.py --data-root "{DATA_ROOT}" --device cuda
# Out:
# FLAT test [baseline_cnn]: {'macro_f1': 0.9759, 'macro_precision': 0.976, 'macro_recall': 0.9766, 'weighted_f1': 0.9809, 'balanced_accuracy': np.float64(0.9766), 'accuracy': 0.9808}
# FLAT test [resnet50]: {'macro_f1': 0.9879, 'macro_precision': 0.989, 'macro_recall': 0.9869, 'weighted_f1': 0.9904, 'balanced_accuracy': np.float64(0.9869), 'accuracy': 0.9904}
# FLAT test [efficientnet_b0]: {'macro_f1': 0.9915, 'macro_precision': 0.9926, 'macro_recall': 0.9907, 'weighted_f1': 0.9936, 'balanced_accuracy': np.float64(0.9907), 'accuracy': 0.9936}
# HIJERARHIJA test: {'end_to_end_macro_f1': 0.9937, 'end_to_end_macro_precision': 0.9948, 'end_to_end_macro_recall': 0.993, 'end_to_end_weighted_f1': 0.9962, 'end_to_end_accuracy': 0.9962, 'species_macro_f1': 0.999, 'species_correct_frac': 0.999, 'errors_total': 31, 'errors_from_species': 8, 'share_of_errors_due_to_species': 0.2581}
#
# Sacuvano: /kaggle/working/Neuronske-mreze/experiments/resnet50_hierarchical/test_metrics.json
